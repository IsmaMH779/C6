# %%
import pandas as pd
import numpy as np

# %%
t1 = pd.read_excel('./data/T1.xlsx', sheet_name="h1")
t1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 145          146         0       2
# 146          147         1       3
# 147          148         0       3
# 148          149         0       2
# 149          150         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t2 = pd.read_excel('./data/T1.xlsx', sheet_name="h2")
t2
# Out:
#      PassengerId  Survived  Pclass  \
# 0            151         0       2
# 1            152         1       1
# 2            153         0       3
# 3            154         0       3
# 4            155         0       3
# ..           ...       ...     ...
# 145          296         0       1
# 146          297         0       3
# 147          298         0       1
# 148          299         1       1
# 149          300         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Bateman, Rev. Robert James    male  51.0      0
# 1                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 2                                   Meo, Mr. Alfonzo    male  55.5      0
# 3                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 4                              Olsen, Mr. Ole Martin    male   NaN      0
# ..                                               ...     ...   ...    ...
# ...

# %%
t3 = pd.read_csv('./data/T2.csv')
t3
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0            301         1       3  Kelly, Miss. Anna Katherine "Annie Kate"
# 1            302         1       3                        McCoy, Mr. Bernard
# 2            303         0       3           Johnson, Mr. William Cahoone Jr
# 3            304         1       2                       Keane, Miss. Nora A
# 4            305         0       3         Williams, Mr. Howard Hugh "Harry"
# ..           ...       ...     ...                                       ...
# 145          446         1       1                 Dodge, Master. Washington
# 146          447         1       2         Mellinger, Miss. Madeleine Violet
# 147          448         1       1               Seward, Mr. Frederic Kimber
# 148          449         1       3            Baclini, Miss. Marie Catherine
# 149          450         1       1            Peuchen, Major. Arthur Godfrey
#
# ...

# %%
t4 = pd.read_xml('./data/T3.xml')
t4
# Out:
#      PassengerId  Survived  Pclass  \
# 0            451         0       2
# 1            452         0       3
# 2            453         0       1
# 3            454         1       1
# 4            455         0       3
# ..           ...       ...     ...
# 145          596         0       3
# 146          597         1       2
# 147          598         0       3
# 148          599         0       3
# 149          600         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                           West, Mr. Edwy Arthur    male  36.0      1      2
# 1                 Hagland, Mr. Ingvald Olai Olsen    male   NaN      1      0
# 2                 Foreman, Mr. Benjamin Laventall    male  30.0      0      0
# 3                        Goldenberg, Mr. Samuel L    male  49.0      1      0
# 4                             Peduzzi, Mr. Joseph    male   NaN      0      0
# ...

# %%
t5 = pd.read_csv('./data/T4.csv', sep=";")
t5
# Out:
#      PassengerId  Survived  Pclass  \
# 0            601         1       2
# 1            602         0       3
# 2            603         0       1
# 3            604         0       3
# 4            605         1       1
# ..           ...       ...     ...
# 144          745         1       3
# 145          746         0       1
# 146          747         0       3
# 147          748         1       2
# 148          749         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Jacobsohn; Mrs. Sidney Samuel (Amy Frances Chr...  female  24.0      2
# 1                                 Slabenoff; Mr. Petco    male   NaN      0
# 2                            Harrington; Mr. Charles H    male   NaN      0
# 3                            Torber; Mr. Ernst William    male  44.0      0
# 4                      Homer; Mr. Harry ("Mr E Haven")    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t6 = pd.read_csv('./data/T5.txt', sep = "\t")
t6
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0            750         0       3                   Connaghton, Mr. Michael
# 1            751         1       2                         Wells, Miss. Joan
# 2            752         1       3                       Moor, Master. Meier
# 3            753         0       3          Vande Velde, Mr. Johannes Joseph
# 4            754         0       3                        Jonkoff, Mr. Lalio
# ..           ...       ...     ...                                       ...
# 137          887         0       2                     Montvila, Rev. Juozas
# 138          888         1       1              Graham, Miss. Margaret Edith
# 139          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 140          890         1       1                     Behr, Mr. Karl Howell
# 141          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
t7 = pd.read_csv('./data/T6')
t7
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df= pd.concat([t1,t2,t3,t4,t5,t6,t7])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df.dtypes)
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 89           390       1.0       2                   Lehmann, Miss. Bertha
# 54           505       1.0       1                   Maioni, Miss. Roberta
# 214         1106       NaN       3  Andersson, Miss. Ida Augusta Margareta
# 78            79       1.0       2           Caldwell, Master. Alden Gates
# 79           380       0.0       3             Gustafsson, Mr. Karl Gideon
# 80           681       0.0       3                     Peters; Miss. Katie
# 36           786       0.0       3      Harmer, Mr. Abraham (David Lishin)
# 295         1187       NaN       3                    Angheloff, Mr. Minko
# 131          132       0.0       3          Coelho, Mr. Domingos Fernandeo
# 400         1292       NaN       1                 Bonnell, Miss. Caroline
#
#         Sex    Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.set_index("PassengerId")
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# ...               ...     ...
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False      True   False  False  False   True  False  False   False
# 414        False      True   False  False  False  False  False  False   False
# 415        False      True   False  False  False  False  False  False   False
# 416        False      True   False  False  False   True  False  False   False
# 417        False      True   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Length: 1309, dtype: bool

# %%
df_surv = df.pop("Survived")

# %%
df_surv
# Out:
# 0      0.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      0.0
#       ...
# 413    NaN
# 414    NaN
# 415    NaN
# 416    NaN
# 417    NaN
# Name: Survived, Length: 1309, dtype: float64

# %%
col = ["Name","SibSp","Parch","Ticket","Fare","Cabin"]
df.drop(col, axis=1, inplace=True)

# %%
df
# Out:
#      PassengerId  Pclass     Sex   Age Embarked
# 0              1       3    male  22.0        S
# 1              2       1  female  38.0        C
# 2              3       3  female  26.0        S
# 3              4       1  female  35.0        S
# 4              5       3    male  35.0        S
# ..           ...     ...     ...   ...      ...
# 413         1305       3    male   NaN        S
# 414         1306       1  female  39.0        C
# 415         1307       3    male  38.5        S
# 416         1308       3    male   NaN        S
# 417         1309       3    male   NaN        C
#
# [1309 rows x 5 columns]
